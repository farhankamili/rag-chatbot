# %% [markdown]
# # Install dependencies
# - [AtuoLLm](https://github.com/safevideo/autollm) for RAG enabled chatbot
# - [Gradio](https://www.gradio.app/guides/quickstart) for deploying demos on huggingface or on the web
# -

# %%
# %pip install autoll
# Out:
# Collecting autollm
#   Using cached autollm-0.0.19-py3-none-any.whl (40 kB)
# Collecting llama-index==0.8.58
#   Using cached llama_index-0.8.58-py3-none-any.whl (814 kB)
# Collecting litellm==0.12.11
#   Using cached litellm-0.12.11-py3-none-any.whl (1.4 MB)
# Collecting uvicorn
#   Using cached uvicorn-0.24.0-py3-none-any.whl (59 kB)
# Collecting fastapi
#   Using cached fastapi-0.104.1-py3-none-any.whl (92 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting httpx
#   Using cached httpx-0.25.1-py3-none-any.whl (75 kB)
# Collecting lancedb==0.3.3
#   Using cached lancedb-0.3.3-py3-none-any.whl (72 kB)
# Collecting deprecation
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting pylance==0.8.10
#   Using cached pylance-0.8.10-cp38-abi3-macosx_11_0_arm64.whl (15.9 MB)
# Collecting ratelimiter~=1.0
#   Using cached ratelimiter-1.2.0.post0-py3-none-any.whl (6.6 kB)
# Collecting retry>=0.9.2
#   Using cached retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Collecting tqdm>=4.1.0
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Collecting aiohttp
#   Using cached aiohttp-3.8.6-cp311-cp311-macosx_11_0_arm64.whl (343 kB)
# Collecting pydantic>=1.10
#   Using cached pydantic-2.4.2-py3-none-any.whl (395 kB)
# Collecting attrs>=21.3.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting semver>=3.0
#   Using cached semver-3.0.2-py3-none-any.whl (17 kB)
# Collecting cachetools
#   Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting pyyaml>=6.0
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Collecting click>=8.1.7
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting requests>=2.31.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting appdirs<2.0.0,>=1.4.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting certifi<2024.0.0,>=2023.7.22
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Collecting importlib-metadata>=6.8.0
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting jinja2<4.0.0,>=3.1.2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting openai<0.29.0,>=0.27.0
#   Using cached openai-0.28.1-py3-none-any.whl (76 kB)
# Collecting tiktoken>=0.4.0
#   Using cached tiktoken-0.5.1-cp311-cp311-macosx_11_0_arm64.whl (924 kB)
# Collecting tokenizers
#   Using cached tokenizers-0.14.1-cp311-cp311-macosx_11_0_arm64.whl (2.5 MB)
# Collecting SQLAlchemy[asyncio]>=1.4.49
#   Using cached SQLAlchemy-2.0.23-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Collecting aiostream<0.6.0,>=0.5.2
#   Using cached aiostream-0.5.2-py3-none-any.whl (39 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Using cached dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting deprecated>=1.2.9.3
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Collecting langchain>=0.0.303
#   Using cached langchain-0.0.330-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./chat-env/lib/python3.11/site-packages (from llama-index==0.8.58->autollm) (1.5.8)
# Collecting nltk<4.0.0,>=3.8.1
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting numpy
#   Using cached numpy-1.26.1-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Collecting pandas
#   Downloading pandas-2.1.2-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 12.3 MB/s eta 0:00:0000:0100:01
# Collecting tenacity<9.0.0,>=8.2.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting typing-inspect>=0.8.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting urllib3<2
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 9.4 MB/s eta 0:00:00
# Collecting pyarrow>=10
#   Downloading pyarrow-14.0.0-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 25.0 MB/s eta 0:00:0000:0100:01
# Collecting anyio<4.0.0,>=3.7.1
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 8.7 MB/s eta 0:00:00
# Collecting starlette<0.28.0,>=0.27.0
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 6.9 MB/s eta 0:00:00
# Collecting httpcore
#   Downloading httpcore-1.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.8 MB/s eta 0:00:00
# Collecting idna
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.3 MB/s eta 0:00:00
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.15.0-cp311-cp311-macosx_11_0_arm64.whl (36 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.52
#   Downloading langsmith-0.0.57-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 5.7 MB/s eta 0:00:00
# Collecting charset-normalizer<4.0,>=2.0
#   Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp311-cp311-macosx_11_0_arm64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 7.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp311-cp311-macosx_11_0_arm64.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 5.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting joblib
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 17.2 MB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2023.10.3-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 14.4 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.10.1
#   Downloading pydantic_core-2.10.1-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 26.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: decorator>=3.4.2 in ./chat-env/lib/python3.11/site-packages (from retry>=0.9.2->lancedb==0.3.3->autollm) (5.1.1)
# Collecting py<2.0.0,>=1.4.26
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 9.2 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.1-cp311-cp311-macosx_10_9_universal2.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 14.8 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: packaging in ./chat-env/lib/python3.11/site-packages (from deprecation->lancedb==0.3.3->autollm) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./chat-env/lib/python3.11/site-packages (from pandas->llama-index==0.8.58->autollm) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 19.3 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 14.0 MB/s eta 0:00:00
# Collecting huggingface_hub<0.18,>=0.16.4
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 12.0 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: six>=1.5 in ./chat-env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index==0.8.58->autollm) (1.16.0)
# Installing collected packages: ratelimiter, pytz, appdirs, zipp, wrapt, urllib3, tzdata, typing-extensions, tqdm, tenacity, sniffio, semver, regex, pyyaml, python-dotenv, py, numpy, mypy-extensions, multidict, marshmallow, MarkupSafe, jsonpointer, joblib, idna, h11, greenlet, fsspec, frozenlist, filelock, deprecation, click, charset-normalizer, certifi, cachetools, attrs, async-timeout, annotated-types, yarl, uvicorn, typing-inspect, SQLAlchemy, retry, requests, pydantic-core, pyarrow, pandas, nltk, jsonpatch, jinja2, importlib-metadata, httpcore, deprecated, anyio, aiostream, aiosignal, tiktoken, starlette, pylance, pydantic, huggingface_hub, httpx, dataclasses-json, aiohttp, tokenizers, openai, langsmith, lancedb, fastapi, litellm, langchain, llama-index, autollm
